# %%
import pandas as pd

# %%
xls=pd.ExcelFile('szotar_2.1.xlsx')
df1 = pd.read_excel(xls, 'Orban_kormany')
df2 = pd.read_excel(xls, 'elnökségi tagok')
df3 = pd.read_excel(xls, 'EP képviselők')
df4 = pd.read_excel(xls, 'EgyéniVK.képviselők')
df4 = pd.read_excel(xls, 'OrszágosL.Képviselők')
df4 = pd.read_excel(xls, 'polgi')
df4 = pd.read_excel(xls, 'Fidesz Tagok')
df4 = pd.read_excel(xls, 'Others')

# %%
xls.sheet_names
# Out:
# ['Orban_kormany',
#  'elnökségi tagok',
#  'EP képviselők',
#  'EgyéniVK.képviselők',
#  'OrszágosL.Képviselők',
#  'polgi',
#  'Fidesz Tagok',
#  'Others']

# %%
dfs=[pd.read_excel(xls,sheet) for i, sheet in enumerate(xls.sheet_names)]

# %%
[[name] for df in dfs for name in df['name_list'] if type(name) is not float]
# Out:
# [['Fónagy János'],
#  ['Biró Marcell'],
#  ['Juhász Edit'],
#  ['Kovács József'],
#  ['Orbán Balázs'],
#  ['Janó Márk'],
#  ['Azbej Tristan'],
#  ['Aszódi Attila'],
#  ['Kovács Pál'],
#  ['Becskeházi Attila'],
#  ['Fürjes Balázs'],
#  ['Potápi Árpád János'],
#  ['Soltész Miklós'],
#  ['Takács Szabolcs Ferenc'],
#  ['Tuzson Bence'],
#  ['György István'],
#  ['Varga Judit'],
#  ['Dömötör Csaba'],
#  ['Vidoven Árpád'],
#  ['Rédey Krisztina'],
#  ['Nagy János'],
#  ['Kovács Zoltán'],
#  ['Tuzson Bence'],
#  ['Farkas Sándor'],
#  ['Tomasitz István'],
#  ['Szinay Attila'],
#  ['Bitay Márton Örs'],
#  ['Zambó Péter'],
#  ['Feldman Zsolt'],
#  ['Kis Miklós Zsolt'],
#  ['Rácz András'],
#  ['Zsigó Róbert'],
#  ['Kontrát Károly'],
#  ['Felkai László'],
#  ['Pogácsás Tibor'],
#  ['Rétvári Bence'],
#  ['Latorcai Csaba'],
#  ['Bódis József'],
#  ['Maruzsa Zoltán'],
#  ['Fekete Péter'],
#  ['Fülöp Attila'],
#  ['Nagy Anikó'],
#  ['Horváth Ildikó'],
#  ['Pacsay-Tomassich Orsolya'],
# ...

# %%
dfs[1]['name_list']
# Out:
# 0        Dr. Semjén Zsolt
# 1      Dr. Hargitai János
# 2       Dr. Surján László
# 3           Azbej Tristan
# 4         Dr. Bagdy Gábor
#               ...
# 104            Mach Péter
# 105           Szabó Tímea
# 106          Tordai Bence
# 107         Burány Sándor
# 108          Mellár Tamás
# Name: name_list, Length: 109, dtype: object

# %%
dfs[2]
# Out:
#        Bocskor Andrea    Fidesz
# 0    Gyöngyösi Márton    Jobbik
# 1           Gál Kinga    Fidesz
# 2          Tóth Edina    Fidesz
# 3     Hölvényi György    Fidesz
# 4           Kósa Ádám    Fidesz
# 5        Cseh Katalin  Momentum
# 6         Győri Enikő    Fidesz
# 7        Dobrev Klára        DK
# 8      Ujhelyi István      MSZP
# 9        Gyürk András    Fidesz
# 10       Járóka Lívia    Fidesz
# 11       Rónai Sándor        DK
# 12   Trócsányi László    Fidesz
# 13      Deutsch Tamás    Fidesz
# 14  Donáth Anna Júlia  Momentum
# 15      Szájer József    Fidesz
# 16       Molnár Csaba        DK
# 17    Hidvéghi Balázs    Fidesz
# 18         Deli Andor    Fidesz
# 19  Ara-Kovács Attila        DK
