# %%
import glob
import datetime
import glob
import stanza
import pandas as pd
import time
import sys

# %%
def filetime(file):
    year=file.split('/')[-1][5:9]
    month=file.split('/')[-1][10:12]
    day=file.split('/')[-1][13:15]
    hour=file.split('/')[-1][16:18]
    return [int(each) for each in [year, month, day, hour]]

# %%
stanza.download('hu')
nlp = stanza.Pipeline('hu')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.0.0.json: 115kB [00:00, 32.3MB/s]
# 2020-07-19 19:48:04 INFO: Downloading default packages for language: hu (Hungarian)...
# 2020-07-19 19:48:05 INFO: File exists: /mnt/volume/jupyter/stanza_resources/hu/default.zip.
# 2020-07-19 19:48:09 INFO: Finished downloading models and saved to /mnt/volume/jupyter/stanza_resources.
# 2020-07-19 19:48:09 INFO: Loading these models for language: hu (Hungarian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | szeged  |
# | pos       | szeged  |
# | lemma     | szeged  |
# | depparse  | szeged  |
# =======================
#
# 2020-07-19 19:48:09 INFO: Use device: cpu
# 2020-07-19 19:48:09 INFO: Loading: tokenize
# 2020-07-19 19:48:09 INFO: Loading: pos
# 2020-07-19 19:48:11 INFO: Loading: lemma
# 2020-07-19 19:48:11 INFO: Loading: depparse
# 2020-07-19 19:48:13 INFO: Done loading processors!

# %%
def onlywithneighbours(ofthislist):
    try:
        filtered = [each for each in ofthislist 
                    if each+1 in ofthislist or each-1 in ofthislist]
    except TypeError:
        filtered = [each for each in ofthislist 
                    if str(int(each)+1) in ofthislist or str(int(each)-1) in ofthislist]
    return filtered

# %%
def split_into_numerical_sequences(inlist):

    inlist=sorted(inlist)

    breakindeces=[i for i,j in enumerate(inlist)
                    if (j+1 not in inlist and j in inlist)]

    sublists=[]
    for index, each in enumerate(breakindeces):
        if index==0:
            sublists.append([x for x in inlist
                               if x<=inlist[each]])
        if index!=0:
            sublists.append([x for x in inlist
                               if x<=inlist[each] and x>inlist[breakindeces[index-1]]])

    return sublists

# %%
def stanzanamesearch(text):

    try: doc = nlp(text)
    except IndexError: return []
    
    propns_and_their_positions_dictlist = [{
    #word.id:word.lemma
    word.id:word.text
    for word in sentence.words if word.upos == 'PROPN'}
    for sentence in doc.sentences]

    propns_with_at_least_one_propn_neighbour = [[
    eachdict[eachkey]
    for eachkey in sorted(onlywithneighbours(list(eachdict.keys())))]
    for eachdict in propns_and_their_positions_dictlist]

    propn_ids_with_at_least_one_propn_neighbour = [[
    int(eachkey)
    for eachkey in sorted(onlywithneighbours(list(eachdict.keys())))]
    for eachdict in propns_and_their_positions_dictlist]

    propn_id_sequences_with_at_least_one_propn_neighbour=[
    split_into_numerical_sequences(eachsublist)
    for eachsublist in propn_ids_with_at_least_one_propn_neighbour]

    res=[]
    for sentenceindex, eachsentence in enumerate(propn_id_sequences_with_at_least_one_propn_neighbour):
        for sequenceindex, eachsequence in enumerate(eachsentence):
            name=[]
            for wordindex, eachword in enumerate(eachsequence):
                name.append(propns_and_their_positions_dictlist[sentenceindex][str(eachword)])
            name=' '.join(name)
            res.append(name)

    return list(set(res))

# %%
def validalias(alias):
    if len(str(alias).strip()) > 5 and len(str(alias).strip().split(' ')) > 1: return True
    else: return False

# %%
def matchfinder(text,searchforthese):
    matches=[alias
             for persondata_searchtarget in searchforthese
             for alias in persondata_searchtarget
             if validalias(alias) and alias.lower() in str(text).lower()]
    return matches

# %%
def fillextracols(whichdictionary, whichrowtofill, withthislist, unlessitslongerthanthis):
    if not len(withthislist) > unlessitslongerthanthis and len(withthislist)>0:
        for i, e in enumerate(withthislist):
            targetdf.loc[whichrowtofill,whichdictionary+str(i)]=e

# %%
def prepare_extra_columns(num_of_columns_for_each_dict):
    for each in num_of_columns_for_each_dict:
        for index in range(num_of_columns_for_each_dict[each]):
            targetdf[each + str(index)]=''

# %%
class dictionary_class:
    def __init__(self, name, maxcolnum, searchlist=None, geo=False):
        self.name = name
        self.maxcolnum = maxcolnum
        self.searchlist = searchlist
        self.geo = geo

# %%
def searchlist_maker(csv,excelfile=False,multisheet=False,columnsfiltered=False, headerwechoose='name_list',**kwargs):
    
    if not multisheet:
        if excelfile: persondatadict = pd.read_excel(csv)

        else:
            persondatadict = pd.read_csv(csv)

        if 'alias_separator' in kwargs:
            persondata_searchlist = [[eachalias.strip()
                                    for eachalias in eachperson.split(kwargs['alias_separator'])]
                                    for eachperson in persondatadict[headerwechoose]
                                    if type(eachperson) != float]
        else:
            persondata_searchlist = [[each]
                                    for each in persondatadict[headerwechoose]]

    if multisheet:
        
        if not columnsfiltered:

            xls=pd.ExcelFile(csv)
            dfs=[pd.read_excel(xls,sheet) for i, sheet in enumerate(xls.sheet_names)]
            persondata_searchlist=[[name] for df in dfs for name in df['name_list'] if type(name) is not float]

        if columnsfiltered:
            
            unifieddf=pd.concat([pd.read_excel(csv, sheetname)[column]
                        for sheetname in pd.ExcelFile(csv).sheet_names
                        for column in pd.read_excel(csv, sheetname)
                        if 'LOOKFOR' in column]).dropna().drop_duplicates()
            
            persondata_searchlist = [[each] for each in unifieddf]
            
    return persondata_searchlist

# %%
dictionaries=[
dictionary_class('person_data',
           10,
           searchlist_maker('/mnt/volume/jupyter/szokereso/person_data-1592394309231_utf8.csv',alias_separator='|')),
dictionary_class('wikilist',
           5,
           searchlist_maker('/mnt/volume/jupyter/szokereso/A_negyedik_Orbán-kormany_allamtitkarainak_listaja.csv')),
dictionary_class('stanza',
           10),
dictionary_class('settlement_list',
           5,
           searchlist_maker('/mnt/volume/jupyter/szokereso/List of Settlements_m2.xlsx', excelfile=True,headerwechoose='settlement_name'),
           geo=True),
dictionary_class('szotar_2.1',
           10,
           searchlist_maker('/mnt/volume/jupyter/szokereso/szotar_2.1.xlsx',multisheet=True)),
dictionary_class('instit_dict',
            10,
            searchlist_maker('/mnt/volume/jupyter/szokereso/instit_dict_2.1_updated_headers.xlsx',
                             multisheet=True,
                             columnsfiltered=True))
            ]

# %%
def get_files_sorted_by_date_after_a_date(look_for_this_pattern,cutoffdate):
    
    csvs = glob.glob(look_for_this_pattern)
    datetimes=[datetime.datetime(int(each.split('/')[-1][5:9]),
                             int(each.split('/')[-1][10:12]),
                             int(each.split('/')[-1][13:15]),
                             int(each.split('/')[-1][16:18]),
                             int(each.split('/')[-1][19:21]),
                             int(each.split('/')[-1][22:24])) for each in csvs]

    dt_csvs_filtered=[[dt, csv] for dt, csv in zip(datetimes,csvs) if dt > datetime.datetime(*cutoffdate)]
    
    sorted_filtered_csvs = [csv
                        for _, csv in sorted(
                                         zip([eachpair[0] for eachpair in dt_csvs_filtered],
                                             [eachpair[1] for eachpair in dt_csvs_filtered]))]
    
    return sorted_filtered_csvs

# %%
debugmode = False
wildcard = '/mnt/volume/anagy/mediascraper/mediaScraper/output/data*csv'

todofiles=get_files_sorted_by_date_after_a_date('/mnt/volume/anagy/mediascraper/mediaScraper/output/data*csv',
                                               [2020,7,8,0])
while len(todofiles) != 0:
    print('processing: '+todofiles[0])    
    
    targetcsv=todofiles[0]
    try:
        targetdf = pd.read_csv(targetcsv)

        prepare_extra_columns({dictionary.name: dictionary.maxcolnum for dictionary in dictionaries})

        cells = list(targetdf['TEXT'])

        start_time = time.time()
        for idictionary, dictionary in enumerate(dictionaries):
            if idictionary==5 or not debugmode:
            #if dictionary.name == 'instit_dict':
                for icell, cell in enumerate(cells):
                    if type(cell) is not float:
                        if icell > -1 or not debugmode:
                            if icell%10==0: print(icell)
                            if dictionary.searchlist is not None:
                                fillextracols(dictionary.name,icell,matchfinder(cell,dictionary.searchlist),dictionary.maxcolnum)
                                print('hw')
                            if dictionary.searchlist is None:
                                fillextracols(dictionary.name,icell,stanzanamesearch(cell),dictionary.maxcolnum)
        end_time = time.time()
        print("--- %s seconds ---" % (time.time() - start_time))
        if not debugmode: targetdf.to_csv('/mnt/volume/jupyter/szokereso/resultfiles/'+targetcsv.split('/')[-1].split('.')[0]+'_szokereso_result.csv')
        print(targetcsv)
    except KeyboardInterrupt:
        print('KeyboardInterrupt')
        break
    except:
        the_type, the_value, the_traceback = sys.exc_info()
        outlist = [the_type, the_value, targetcsv, dictionary.name, icell]
        with open('/mnt/volume/jupyter/szokereso/resultfiles/'+targetcsv.split('/')[-1].split('.')[0]+'_ERRORLOG.txt', 'w') as f:
            for item in outlist:
                f.write("%s\n" % item)
                
    todofiles=get_files_sorted_by_date_after_a_date('/mnt/volume/anagy/mediascraper/mediaScraper/output/data*csv',
                                                     filetime(todofiles[0])[:3]+[filetime(todofiles[0])[-1]+1]) # hour increased by 1
# Out:
# processing: /mnt/volume/anagy/mediascraper/mediaScraper/output/data_2020-07-08_00:00:31.csv
# 0
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 10
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 20
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 30
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 40
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 50
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 60
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 70
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 80
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 90
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 100
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 110
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 120
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 130
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 140
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 150
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 160
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 170
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 180
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 190
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 200
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 210
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 220
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 230
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 240
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 250
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 260
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 270
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 280
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 290
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 300
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 310
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 320
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 330
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 340
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 350
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 360
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 370
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 380
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 390
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 400
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 410
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 420
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 430
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 440
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 450
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 460
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 470
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 480
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 490
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 500
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 510
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 520
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 530
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 540
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 550
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 560
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 570
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 580
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 590
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 600
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 610
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 620
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 630
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 640
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 650
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 660
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 670
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 680
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 690
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 700
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 710
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 720
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 730
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 740
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 750
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 760
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 770
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 780
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 790
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 800
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 810
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 820
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 830
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 840
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 850
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 860
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 870
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 880
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 890
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 900
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 910
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 920
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 930
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 940
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 950
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 960
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 970
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 980
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 990
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1000
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1010
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1020
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1030
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1040
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1050
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1060
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1070
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1080
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1090
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1100
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1110
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1120
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1130
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1140
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1150
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1160
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1170
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1180
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1190
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1200
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1210
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1220
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1230
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1240
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1250
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1260
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1270
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1280
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1290
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1300
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1310
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1320
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1330
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1340
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1350
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1360
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1370
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1380
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1390
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1400
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1410
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1420
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1430
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1440
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1450
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1460
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1470
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1480
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1490
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1500
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1510
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1520
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1530
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1540
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1550
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1560
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1570
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1580
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1590
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1600
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1610
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1620
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1630
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1640
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1650
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1660
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1670
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1680
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1690
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1700
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1710
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1720
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1730
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1740
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1750
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1760
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1770
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1780
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1790
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1800
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1810
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1820
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1830
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1840
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1850
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1860
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1870
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1880
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1890
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1900
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1910
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1920
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1930
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1940
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1950
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1960
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1970
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1980
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 1990
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2000
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2010
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2020
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2030
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2040
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2050
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2060
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2070
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2080
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2090
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2100
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2110
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2120
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2130
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2140
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2150
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2160
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2170
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2180
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2190
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2200
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2210
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2220
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2230
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2240
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2250
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2260
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2270
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2280
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2290
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2300
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2310
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2320
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2330
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2340
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2350
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2360
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2370
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2380
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2390
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2400
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2410
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2420
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2430
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2440
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2450
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2460
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2470
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2480
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2490
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2500
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2510
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2520
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2530
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2540
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2550
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2560
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2570
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2580
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2590
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2600
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2610
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2620
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2630
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2640
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2650
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2660
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2670
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2680
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2690
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2700
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2710
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2720
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2730
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2740
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2750
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2760
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2770
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2780
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2790
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2800
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2810
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2820
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2830
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2840
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2850
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2860
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2870
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2880
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2890
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2900
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2910
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2920
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2930
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2940
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2950
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2960
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2970
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2980
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 2990
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3000
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3010
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3020
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3030
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3040
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3050
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3060
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3070
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3080
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3090
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3100
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3110
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3120
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3130
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3140
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3150
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3160
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3170
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3180
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3190
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3200
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3210
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3220
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3230
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3240
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3250
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3260
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3270
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3280
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3290
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3300
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3310
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3320
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3330
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3340
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3350
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3360
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3370
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3380
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3390
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3400
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3410
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3420
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3430
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3440
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3450
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3460
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3470
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3480
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3490
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3500
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3510
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3520
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3530
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3540
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3550
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3560
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3570
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3580
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3590
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3600
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3610
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3620
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3630
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3640
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3650
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3660
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3670
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3680
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3690
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3700
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# 3710
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# hw
# --- 28.359522581100464 seconds ---
# /mnt/volume/anagy/mediascraper/mediaScraper/output/data_2020-07-08_00:00:31.csv
