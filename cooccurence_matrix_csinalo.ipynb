# %%
import pandas as pd

# %%
limit=100

# %%
df=pd.read_csv('resultfiles/data_2020-06-28_08:01:41_szokereso_result.csv')

# %%
dictstrings = ['person_data', 'wikilist','stanza','settlement_list','szotar_2.1']
dictcols = [col for col in df.columns if any([dictstring in col for dictstring in dictstrings])]

# %%
uniques = pd.concat([df[col] for col in dictcols]).dropna().unique()

# %%
cooc = pd.DataFrame(index=uniques, columns=uniques)

# %%
cooc
# Out:
#                        Balogh Edina Karácsony Tamás Stohl András Rubint Réka  \
# Balogh Edina                    NaN             NaN          NaN         NaN
# Karácsony Tamás                 NaN             NaN          NaN         NaN
# Stohl András                    NaN             NaN          NaN         NaN
# Rubint Réka                     NaN             NaN          NaN         NaN
# Horváth Éva                     NaN             NaN          NaN         NaN
# ...                             ...             ...          ...         ...
# All lives                       NaN             NaN          NaN         NaN
# Rettegett Iván                  NaN             NaN          NaN         NaN
# #### „Mr. Oroszország”          NaN             NaN          NaN         NaN
# Budapest V. kerület             NaN             NaN          NaN         NaN
# Budapest VII. kerület           NaN             NaN          NaN         NaN
#
#                        Horváth Éva Hajdú Péter Friderikusz Sándor  \
# Balogh Edina                   NaN         NaN                NaN
# Karácsony Tamás                NaN         NaN                NaN
# Stohl András                   NaN         NaN                NaN
# Rubint Réka                    NaN         NaN                NaN
# Horváth Éva                    NaN         NaN                NaN
# ...                            ...         ...                ...
# All lives                      NaN         NaN                NaN
# Rettegett Iván                 NaN         NaN                NaN
# #### „Mr. Oroszország”         NaN         NaN                NaN
# Budapest V. kerület            NaN         NaN                NaN
# Budapest VII. kerület          NaN         NaN                NaN
#
#                        Schobert Norbert Xantus Barbara Őze Lajos  ...  \
# Balogh Edina                        NaN            NaN       NaN  ...
# Karácsony Tamás                     NaN            NaN       NaN  ...
# Stohl András                        NaN            NaN       NaN  ...
# Rubint Réka                         NaN            NaN       NaN  ...
# Horváth Éva                         NaN            NaN       NaN  ...
# ...                                 ...            ...       ...  ...
# All lives                           NaN            NaN       NaN  ...
# Rettegett Iván                      NaN            NaN       NaN  ...
# #### „Mr. Oroszország”              NaN            NaN       NaN  ...
# Budapest V. kerület                 NaN            NaN       NaN  ...
# Budapest VII. kerület               NaN            NaN       NaN  ...
#
#                        Nemzeti Színház Csorba Győzővel Magyar Nemzetig  \
# Balogh Edina                       NaN             NaN             NaN
# Karácsony Tamás                    NaN             NaN             NaN
# Stohl András                       NaN             NaN             NaN
# Rubint Réka                        NaN             NaN             NaN
# Horváth Éva                        NaN             NaN             NaN
# ...                                ...             ...             ...
# All lives                          NaN             NaN             NaN
# Rettegett Iván                     NaN             NaN             NaN
# #### „Mr. Oroszország”             NaN             NaN             NaN
# Budapest V. kerület                NaN             NaN             NaN
# Budapest VII. kerület              NaN             NaN             NaN
#
#                        Totyik Tamás Republikánus Országos Bizottság All lives  \
# Balogh Edina                    NaN                             NaN       NaN
# Karácsony Tamás                 NaN                             NaN       NaN
# Stohl András                    NaN                             NaN       NaN
# Rubint Réka                     NaN                             NaN       NaN
# Horváth Éva                     NaN                             NaN       NaN
# ...                             ...                             ...       ...
# All lives                       NaN                             NaN       NaN
# Rettegett Iván                  NaN                             NaN       NaN
# #### „Mr. Oroszország”          NaN                             NaN       NaN
# Budapest V. kerület             NaN                             NaN       NaN
# Budapest VII. kerület           NaN                             NaN       NaN
#
#                        Rettegett Iván #### „Mr. Oroszország”  \
# Balogh Edina                      NaN                    NaN
# Karácsony Tamás                   NaN                    NaN
# Stohl András                      NaN                    NaN
# Rubint Réka                       NaN                    NaN
# Horváth Éva                       NaN                    NaN
# ...                               ...                    ...
# All lives                         NaN                    NaN
# Rettegett Iván                    NaN                    NaN
# #### „Mr. Oroszország”            NaN                    NaN
# Budapest V. kerület               NaN                    NaN
# Budapest VII. kerület             NaN                    NaN
#
#                        Budapest V. kerület Budapest VII. kerület
# Balogh Edina                           NaN                   NaN
# Karácsony Tamás                        NaN                   NaN
# Stohl András                           NaN                   NaN
# Rubint Réka                            NaN                   NaN
# Horváth Éva                            NaN                   NaN
# ...                                    ...                   ...
# All lives                              NaN                   NaN
# Rettegett Iván                         NaN                   NaN
# #### „Mr. Oroszország”                 NaN                   NaN
# Budapest V. kerület                    NaN                   NaN
# Budapest VII. kerület                  NaN                   NaN
#
# [5878 rows x 5878 columns]

# %%
for icoocrow, coocrow in enumerate(cooc.index):
    for icooccol, cooccol in enumerate(cooc.columns):
        if icoocrow ==icooccol: print(icoocrow/limit)
        if icoocrow > icooccol:
            count=0
            for index, row in df[[*dictcols]].iterrows():
                if cooccol in list(row) and coocrow in list(row):
                    count+=1
            cooc.loc[coocrow,cooccol]=count
# Out:
# 0.0
# 0.0001701258931609391
# 0.0003402517863218782
# 0.0005103776794828172
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-10-1791fd430f02> in <module>
#       4         if icoocrow > icooccol:
#       5             count=0
# ----> 6             for index, row in df[[*dictcols]].iterrows():
#       7                 if cooccol in list(row) and coocrow in list(row):
#       8                     count+=1
#
# ~/.local/lib/python3.6/site-packages/pandas/core/frame.py in iterrows(self)
#     950         klass = self._constructor_sliced
#     951         for k, v in zip(self.index, self.values):
# --> 952             s = klass(v, index=columns, name=k)
#     953             yield k, s
#     954
#
# ~/.local/lib/python3.6/site-packages/pandas/core/series.py in __init__(self, data, index, dtype, name, copy, fastpath)
#     305                 data = sanitize_array(data, index, dtype, copy, raise_cast_failure=True)
#     306
# --> 307                 data = SingleBlockManager(data, index, fastpath=True)
#     308
#     309         generic.NDFrame.__init__(self, data, fastpath=True)
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/managers.py in __init__(self, block, axis, do_integrity_check, fastpath)
#    1511
#    1512         if not isinstance(block, Block):
# -> 1513             block = make_block(block, placement=slice(0, len(axis)), ndim=1)
#    1514
#    1515         self.blocks = tuple([block])
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype)
#    3047         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3048
# -> 3049     return klass(values, ndim=ndim, placement=placement)
#    3050
#    3051
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2595             values = np.array(values, dtype=object)
#    2596
# -> 2597         super().__init__(values, ndim=ndim, placement=placement)
#    2598
#    2599     @property
#
# ~/.local/lib/python3.6/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#     121         self.values = values
#     122
# --> 123         if self._validate_ndim and self.ndim and len(self.mgr_locs) != len(self.values):
#     124             raise ValueError(
#     125                 f"Wrong number of items passed {len(self.values)}, "
#
# KeyboardInterrupt:

# %%
cooc=cooc.fillna(0)

# %%
cooc=cooc+cooc.transpose()

# %%
cooc.to_csv('resultfiles/data_2020-06-28_08:01:41_szokereso_result_cooc.csv')

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-6a7d8caa8a27> in <module>
# ----> 1 cooc
#
# NameError: name 'cooc' is not defined

# %%
cooc+cooc.transpose()
# Out:
#    A  B  C  D
# A  0  1  2  0
# B  1  0  1  1
# C  2  1  0  0
# D  0  1  0  0

# %%
for icoocrow, coocrow in enumerate(cooc.index):
    for icooccol, cooccol in enumerate(cooc.columns):
        if icoocrow > icooccol:
            count=0
            for index, row in df[['letter1','letter2']].iterrows():
                if cooccol != coocrow:
                    if cooccol in list(row) and coocrow in list(row):
                        count+=1
            cooc.loc[coocrow,cooccol]=count
cooc=cooc.fillna(0)

# %%
cooc = pd.DataFrame(index=index, columns=column)

# %%
index  = pd.unique(df[['letter1', 'letter2']].values.ravel('K')) #using: https://stackoverflow.com/a/26977495/8565438
column = pd.unique(df[['letter1', 'letter2']].values.ravel('K')) #using: https://stackoverflow.com/a/26977495/8565438

# %%
df
# Out:
#   letter1 letter2  value
# 0       A       A      1
# 1       A       B      2
# 2       B       D      3
# 3       B       C      3
# 4       C       A      7
# 5       C       A      5

# %%
df = pd.DataFrame({'letter1':   ['A','A','B','B','C','C'],
                   'letter2':   ['A','B','D','C','A','A'],
                    'value':[  1,  2,  3,  3,  7,  5]})
