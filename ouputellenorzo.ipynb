# %%
import glob

# %%
lastfile = glob.glob('resultfiles/data_2020-07-14_16:02:07_szokereso_result.csv')[0]

# %%
import pandas as pd

# %%
df = pd.read_csv(lastfile)

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'DOC_ID', 'TITLE', 'URL', 'AGEGROUP', 'OWNTIME',
#        'SCRAPETIME', 'TEXT', 'AUTHOR', 'OUTLET', 'TOP1', 'TOP2', 'TOP4',
#        'TOP8', 'TOP12', 'TOP24', 'TOP48', 'person_data0', 'person_data1',
#        'person_data2', 'person_data3', 'person_data4', 'person_data5',
#        'person_data6', 'person_data7', 'person_data8', 'person_data9',
#        'wikilist0', 'wikilist1', 'wikilist2', 'wikilist3', 'wikilist4',
#        'stanza0', 'stanza1', 'stanza2', 'stanza3', 'stanza4', 'stanza5',
#        'stanza6', 'stanza7', 'stanza8', 'stanza9', 'settlement_list0',
#        'settlement_list1', 'settlement_list2', 'settlement_list3',
#        'settlement_list4', 'szotar_2.10', 'szotar_2.11', 'szotar_2.12',
#        'szotar_2.13', 'szotar_2.14', 'szotar_2.15', 'szotar_2.16',
#        'szotar_2.17', 'szotar_2.18', 'szotar_2.19', 'instit_dict0',
#        'instit_dict1', 'instit_dict2', 'instit_dict3', 'instit_dict4',
# ...

# %%
df['geo2dict0']
# Out:
# 0               Egyesült Királyság
# 1       Jász-Nagykun-Szolnok megye
# 2                              NaN
# 3                              NaN
# 4               Egyesült Királyság
#                    ...
# 3715                           NaN
# 3716       Egyesült Arab Emírségek
# 3717                           NaN
# 3718                           NaN
# 3719                           NaN
# Name: geo2dict0, Length: 3720, dtype: object

# %%
df
# Out:
#       Unnamed: 0  DOC_ID                                              TITLE  \
# 0              0       1  A brit vállalatok 2021-től nem vásárolhatnak a...
# 1              1       2  Három év börtönt kapott a kórházi dolgozókra t...
# 2              2       3  Orbán Viktor volt osztálytársát a neves hadtör...
# 3              3       4  „Nem akarok címlap-cigány lenni!” – Bogdán Lás...
# 4              4       5  Jóval drágábban vett a külügy lélegeztetőgépek...
# ...          ...     ...                                                ...
# 3715        3715    3716  Hármas ikrei lettek volna Coronának a tyúknak ...
# 3716        3716    3717   Ez a három ország indít Mars-szondát a világűrbe
# 3717        3717    3718  Most érkezett: Szlovákiában és Magyarországon ...
# 3718        3718    3719  Kínzó fájdalommal él együtt az orvosai sem tud...
# 3719        3719    3720  Ezért javasol Merkely belföldi nyaralást – Az ...
#
# ...
