# %%
import glob
import pandas as pd

# %%
onlymomFiles = glob.glob('resultfiles/onlymomentum_*')

# %%
len(onlymomFiles)
# Out:
# 128

# %%
df = pd.read_csv(onlymomFiles[0])

# %%
df[~df['momentumdict0'].isna()]
# Out:
#       Unnamed: 0  DOC_ID                                              TITLE  \
# 198          198     199  Soha! Soha! - a Cannes-i Filmfesztivál igazgat...
# 239          239     240  Merkel: Németország mindenképpen kiáll a jogál...
# 339          339     340  Könnyen megszivathatja a közös lista a balolda...
# 407          407     408     Meghalt Bálint Gergő a Vác 17 éves labdarúgója
# 431          431     432  Kormánylapban esett neki Fodor Gábor az ellenz...
# 1139        1139    1140                Nagy a zűrzavar a lakáskiadás körül
# 1321        1321    1322  A Magyar Apartmankiadók Egyesületének alelnöke...
# 1349        1349    1350  Terézváros polgármestere az Airbnb-törvényről:...
# 1697        1697    1698  Becsüljük meg a velünk az értünk élő prófétáka...
# 2196        2196    2197  Tudják hogy bezuhanna a turizmus mégis megfojt...
# 2532        2532    2533  Lenne jobb és igazságosabb mód a kata rendszer...
# ...

# %%
len(glob.glob('resultfiles/onlymomentum/*'))
# Out:
# 286
